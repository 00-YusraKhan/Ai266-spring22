# %%
import pandas as pd
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

# %%
tr_df = pd.read_csv('train.csv')
tst_df = pd.read_csv('test.csv')

# %%
del tr_df['f_27']
del tr_df['f_29']
del tr_df['f_30']
del tst_df['f_27']
del tst_df['f_29']
del tst_df['f_30']

# %%
print(tr_df)
# Out:
#             id      f_00      f_01      f_02      f_03      f_04      f_05  \
# 0            0 -1.373246  0.238887 -0.243376  0.567405 -0.647715  0.839326
# 1            1  1.697021 -1.710322 -2.230332 -0.545661  1.113173 -1.552175
# 2            2  1.681726  0.616746 -1.027689  0.810492 -0.609086  0.113965
# 3            3 -0.118172 -0.587835 -0.804638  2.086822  0.371005 -0.128831
# 4            4  1.148481 -0.176567 -0.664871 -1.101343  0.467875  0.500117
# ...        ...       ...       ...       ...       ...       ...       ...
# 899995  899995  1.380145 -0.038884  0.597111  0.854560  0.684301 -1.058618
# 899996  899996 -1.369789  0.044841  0.015458  0.376565 -0.380529 -0.830815
# 899997  899997  1.386201 -0.961150  0.725994 -0.132844  0.873911 -0.245339
# 899998  899998 -1.590572 -0.509938 -1.715397 -0.249988  1.359933  1.650808
# 899999  899999 -0.636210 -0.425986 -1.826699 -0.598797  1.589577 -0.482298
#
# ...

# %%
print(tst_df)
# Out:
#              id      f_00      f_01      f_02      f_03      f_04      f_05  \
# 0        900000  0.442517  0.174380 -0.999816  0.762741  0.186778 -1.074775
# 1        900001 -0.605598 -0.305715  0.627667 -0.578898 -1.750931  1.355550
# 2        900002  0.303990  2.445110  0.246515  0.818248  0.359731 -1.331845
# 3        900003  0.154053  0.260126 -1.367092 -0.093175 -1.111034 -0.948481
# 4        900004 -1.651904 -0.424266 -0.667356 -0.322124 -0.089462  0.181705
# ...         ...       ...       ...       ...       ...       ...       ...
# 699995  1599995  0.640110  0.897808 -0.523956  1.563760 -0.092281 -0.610867
# 699996  1599996 -0.191771 -0.035246 -0.118533  0.584750  2.126977  0.568659
# 699997  1599997 -0.331704 -0.328845 -1.185503  1.022128 -0.483099 -0.107146
# 699998  1599998 -2.031073 -1.238398  0.964699 -1.045950  0.906064  0.634301
# 699999  1599999 -0.085906 -0.002124  2.227375  0.217145  3.179153 -1.660188
#
# ...

# %%
tr_df=tr_df.drop("id",axis=1)
# Building Machine Learning Models
Y_train = tr_df["target"]
X_train = tr_df.drop("target", axis=1)
X_test  = tst_df.drop("id", axis=1).copy()
print(Y_train)
print(X_train)
print(X_test)
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 899995    1
# 899996    0
# 899997    0
# 899998    0
# 899999    1
# Name: target, Length: 900000, dtype: int64
#             f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0      -1.373246  0.238887 -0.243376  0.567405 -0.647715  0.839326  0.113133
# 1       1.697021 -1.710322 -2.230332 -0.545661  1.113173 -1.552175  0.447825
# 2       1.681726  0.616746 -1.027689  0.810492 -0.609086  0.113965 -0.708660
# 3      -0.118172 -0.587835 -0.804638  2.086822  0.371005 -0.128831 -0.282575
# 4       1.148481 -0.176567 -0.664871 -1.101343  0.467875  0.500117  0.407515
# ...          ...       ...       ...       ...       ...       ...       ...
# 899995  1.380145 -0.038884  0.597111  0.854560  0.684301 -1.058618  1.310699
# 899996 -1.369789  0.044841  0.015458  0.376565 -0.380529 -0.830815 -1.798458
# 899997  1.386201 -0.961150  0.725994 -0.132844  0.873911 -0.245339 -1.045786
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
svm = LinearSVC()
svm.fit(X_train, Y_train)
y_predict=svm.predict(X_test)
print(y_predict)
# Out:
# [0 1 1 ... 0 1 1]

# %%
mufreahCSV = tst_df[['id']]

# %%
mufreahCSV
# Out:
#              id
# 0        900000
# 1        900001
# 2        900002
# 3        900003
# 4        900004
# ...         ...
# 699995  1599995
# 699996  1599996
# 699997  1599997
# 699998  1599998
# 699999  1599999
#
# [700000 rows x 1 columns]

# %%
prd = tst_df.drop(columns=['id'])

# %%
prd.head()
# Out:
#        f_00      f_01      f_02      f_03      f_04      f_05      f_06  f_07  \
# 0  0.442517  0.174380 -0.999816  0.762741  0.186778 -1.074775  0.501888     6
# 1 -0.605598 -0.305715  0.627667 -0.578898 -1.750931  1.355550 -0.190911     1
# 2  0.303990  2.445110  0.246515  0.818248  0.359731 -1.331845  1.358622     3
# 3  0.154053  0.260126 -1.367092 -0.093175 -1.111034 -0.948481  1.119220     0
# 4 -1.651904 -0.424266 -0.667356 -0.322124 -0.089462  0.181705  1.784983     2
#
#    f_08  f_09  ...  f_18      f_19      f_20      f_21      f_22      f_23  \
# 0     6     0  ...     1 -1.128371  2.749347 -1.006400 -1.193879 -2.435736
# 1     3     4  ...     0 -4.424098  1.080762  2.382405  0.149442  1.883322
# 2     3     4  ...     3 -1.523864 -1.406712 -7.026098  1.312277 -5.157192
# 3     0     4  ...     2 -1.404597  3.011085 -0.594532 -3.939475  1.754570
# 4     2     2  ...     2 -1.968516  0.100594  0.084906 -0.985736 -0.130467
#
#        f_24      f_25      f_26        f_28
# ...

# %%
tstPRD = svm.predict(prd)

# %%
print(tstPRD)
# Out:
# [0 1 1 ... 0 1 1]

# %%
mufreahCSV['target'] = tstPRD

# %%
mufreahCSV.head()
# Out:
#        id  target
# 0  900000       0
# 1  900001       1
# 2  900002       1
# 3  900003       1
# 4  900004       0

# %%
mufreahCSV.to_csv('newcompdataset.csv', index=False)
